# %%
import os
import numpy as np
import pandas as pd
import plotly.express as px
import re

# %% [markdown]
# Reading the data

# %%
print(os.listdir(r'C:/Users/ata-d/'))
data = pd.read_csv(r'C:/Users/ata-d/OneDrive/MasaÃ¼stÃ¼/ML/Datasets/covid19_vac_education.csv')
locations = pd.read_csv(r'C:/Users/ata-d/OneDrive/MasaÃ¼stÃ¼/ML/Datasets/Sheet 5.csv', delimiter=';')

# %%
locations['Latitude (generated)'] = locations['Latitude (generated)'].str.replace('[A-Za-z]', '').str.replace(',', '.').astype(float)
locations['Longitude (generated)'] = locations['Longitude (generated)'].str.replace('[A-Za-z]', '').str.replace(',', '.').astype(float)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Cities by Educational Background Distribution

# %%
fig = px.bar(data, y='Cities', x=['College_graduate',
                                  'High_school_graduate', 'Less_than_high_school'],
             barmode='stack', text='value',
             labels={"value": "Distribution of the Educational Background [%]"})
fig.update_layout(title_text='Cities by Educational Background Distribution',
                  title_x=0.5, title_font=dict(size=20))
fig.update_traces(marker=dict(line=dict(color='#000000', width=1)))
fig.update_traces(texttemplate='%{text:.2s}', textposition='inside')
fig.show('png')

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Scatter Plots

# %%
fig = px.scatter(data, x="COVID-19_Vaccination", y="College_graduate", trendline="ols",
                 text='Cities',
                 labels={"College_graduate": "College Graduation Rate [%]",
                         "COVID-19_Vaccination": "Vaccination Rate [%]"})
fig.update_layout(title_text='Cities by College Educational Background',
                  title_x=0.5, title_font=dict(size=20))
fig.update_traces(textposition='top center')
fig.data[1].line.color = 'red'
fig.show('png')

# %%
fig = px.scatter(data, x="COVID-19_Vaccination", y="High_school_graduate", trendline="ols",
                 text='Cities',
                 labels={"High_school_graduate": "High School Graduation Rate [%]",
                         "COVID-19_Vaccination": "Vaccination Rate [%]"})
fig.update_layout(title_text='Cities by High School Educational Background',
                  title_x=0.5, title_font=dict(size=20))
fig.update_traces(textposition='top center')
fig.data[1].line.color = 'red'
fig.show('png')

# %%
fig = px.scatter(data, x="COVID-19_Vaccination", y="Less_than_high_school", trendline="ols",
                 text='Cities',
                 labels={"Less_than_high_school": "Less than High School Rate [%]",
                         "COVID-19_Vaccination": "Vaccination Rate [%]"})
fig.update_layout(title_text='Cities by Less than High School Educational Background',
                  title_x=0.5, title_font=dict(size=20))
fig.update_traces(textposition='top center')
fig.data[1].line.color = 'red'
fig.show('png')

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Cities by Vaccination Rate

# %%
fig = px.bar(data_frame=data, x='COVID-19_Vaccination', y='Cities', color='COVID-19_Vaccination',
             labels={"COVID-19_Vaccination": "Vaccination Rate [%]"})
fig.update_layout(title_text='Cities by Vaccination Rate',
                  title_x=0.5, title_font=dict(size=20))
fig.update_layout(yaxis={'categoryorder': 'total ascending'})
fig.update_traces(marker=dict(line=dict(color='#000000', width=1)))
fig.show('png')

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------
